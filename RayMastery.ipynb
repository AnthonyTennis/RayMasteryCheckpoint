# %%
# %load_ext autoreload
# %autoreload 2
import numpy as np
import sys
import ray
import SampleSort
import qs
ray.init()
# Out:
# 2023-11-14 00:41:15,567	INFO worker.py:1642 -- Started a local Ray instance.
# RayContext(dashboard_url='', python_version='3.10.12', ray_version='2.7.1', ray_commit='9f07c12615958c3af3760604f6dcacc4b3758a47', protocol_version=None)

# %%
def is_sorted(arr):
    if len(arr) <= 1:
        return True
    for i in range(len(arr) - 2):
        if arr[i] > arr[i+1]:
            return False
    return True

# %%
# test this function
arr_1 = []          # t
arr_2 = [1]         # t
arr_3 = [1,1]       # t
arr_4 = [1,2,3,4,5] # t
arr_5 = [1,3,5,2,1] # f
results = [is_sorted(arr_1),is_sorted(arr_2),is_sorted(arr_3),is_sorted(arr_4),is_sorted(arr_5)]
results
# Out:
# [True, True, True, True, False]

# %%
# create an array with 10,000,000 ints from 0 to max size 
arr = np.random.randint(0, sys.maxsize, size=10000000)
available_processors = int(ray.available_resources()['CPU'])
print(available_processors)
# Out:
# 60

# %%
test_arr = np.random.randint(0, 100, size=20)
result = SampleSort.sampleSort(test_arr, available_processors)
is_sorted(result)
# Out:
# Just doing quicksort, bucket size is too small
# True

# %%
# %%time
print(len(arr))
result_ss = SampleSort.sampleSort(arr, available_processors)
print(len(result_ss))
# Out:
# 10000000
# [ 233978057339125469  289255038150580278  290198570720381131
#   401697464361614632  406473589721484086  913522660264946780
#  1003102191652992545 1041234043364246569 1118728569201030670
#  1199517162241363198 1264565941897203603 1265406356294765694
#  1292917677737253890 1401441029411234290 1570652139973254534
#  1680321783166851109 1783198391548658055 2345559498372978242
#  2620394238798177914 2754935711003593074 3006237647084805746
#  3054811938217681317 3101299324286822187 3317526950733496498
#  3348141563821945743 3916452880442745009 4330767390871483853
#  4421996952262147600 4908183699733628987 4985438515237269319
#  5083164816047013458 5299601692274979286 5517800947447699473
#  5647769205676703170 5814237664618191472 6033058532692814479
#  6118165542999515003 6130579306641040569 6158321854357171210
#  6193173674474414880 6311332402964868069 6522912487462457022
#  6535769573756970867 6737219391411140468 7043612606013750712
#  7265791313415693807 7533646908843702613 7539034285531427539
#  7681841478552931410 7696449148972069603 7840462866495485419
#  7904418356807342956 8384781094339593662 8517117890540421459
#  8561263253020177073 8751662418643849337 8777283424229945251
#  8852405318490938447 9127786115882559737]
# <enumerate object at 0x7f8bb9aebb00>
# 253943
# 59603
# 1006
# 120988
# 5195
# 549988
# 96827
# 41194
# 84127
# 87381
# 70553
# 899
# 29555
# 117712
# 182747
# 119436
# 111800
# 610085
# 297833
# 146030
# 272308
# 52719
# 50392
# 234497
# 33294
# 615663
# 448347
# 98412
# 526508
# 83850
# 105838
# 235238
# 236598
# 140515
# 180415
# 237443
# 92407
# 13530
# 30134
# 37626
# 128301
# 229645
# 14066
# 218479
# 332667
# 240781
# 290563
# 5786
# 154920
# 15834
# 156665
# 69574
# 521323
# 142694
# 47803
# 207043
# 27911
# 81157
# 298857
# 103295
# 2023-11-14 00:45:55,661	ERROR worker.py:405 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): ray::call_qs() (pid=1529339, ip=172.17.0.37)
#   File "/home/myuser/RayMasteryCheckpoint/SampleSort.py", line 51, in call_qs
#     return qs.quickSort(bucket, 0, len(bucket)-1)
#   File "/home/myuser/RayMasteryCheckpoint/qs.py", line 35, in quickSort
#     quickSort(array, low, pi - 1)
#   File "/home/myuser/RayMasteryCheckpoint/qs.py", line 35, in quickSort
#     quickSort(array, low, pi - 1)
#   File "/home/myuser/RayMasteryCheckpoint/qs.py", line 35, in quickSort
#     quickSort(array, low, pi - 1)
#   [Previous line repeated 990 more times]
#   File "/home/myuser/RayMasteryCheckpoint/qs.py", line 32, in quickSort
#     pi = partition(array, low, high)
#   File "/home/myuser/RayMasteryCheckpoint/qs.py", line 13, in partition
#     for j in range(low, high):
# RecursionError: maximum recursion depth exceeded in comparison
# 2023-11-14 00:45:55,674	ERROR worker.py:405 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): ray::call_qs() (pid=1529338, ip=172.17.0.37)
#   File "/home/myuser/RayMasteryCheckpoint/SampleSort.py", line 51, in call_qs
#     return qs.quickSort(bucket, 0, len(bucket)-1)
#   File "/home/myuser/RayMasteryCheckpoint/qs.py", line 35, in quickSort
#     quickSort(array, low, pi - 1)
#   File "/home/myuser/RayMasteryCheckpoint/qs.py", line 35, in quickSort
#     quickSort(array, low, pi - 1)
#   File "/home/myuser/RayMasteryCheckpoint/qs.py", line 35, in quickSort
#     quickSort(array, low, pi - 1)
#   [Previous line repeated 990 more times]
#   File "/home/myuser/RayMasteryCheckpoint/qs.py", line 32, in quickSort
#     pi = partition(array, low, high)
#   File "/home/myuser/RayMasteryCheckpoint/qs.py", line 13, in partition
#     for j in range(low, high):
# RecursionError: maximum recursion depth exceeded in comparison
# 2023-11-14 00:46:00,664	ERROR worker.py:405 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): ray::call_qs() (pid=1529335, ip=172.17.0.37)
#   File "/home/myuser/RayMasteryCheckpoint/SampleSort.py", line 51, in call_qs
#     return qs.quickSort(bucket, 0, len(bucket)-1)
#   File "/home/myuser/RayMasteryCheckpoint/qs.py", line 35, in quickSort
#     quickSort(array, low, pi - 1)
#   File "/home/myuser/RayMasteryCheckpoint/qs.py", line 35, in quickSort
#     quickSort(array, low, pi - 1)
#   File "/home/myuser/RayMasteryCheckpoint/qs.py", line 35, in quickSort
#     quickSort(array, low, pi - 1)
#   [Previous line repeated 990 more times]
#   File "/home/myuser/RayMasteryCheckpoint/qs.py", line 32, in quickSort
#     pi = partition(array, low, high)
#   File "/home/myuser/RayMasteryCheckpoint/qs.py", line 13, in partition
#     for j in range(low, high):
# RecursionError: maximum recursion depth exceeded in comparison
# 2023-11-14 00:46:02,665	ERROR worker.py:405 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): ray::call_qs() (pid=1529326, ip=172.17.0.37)
#   File "/home/myuser/RayMasteryCheckpoint/SampleSort.py", line 51, in call_qs
#     return qs.quickSort(bucket, 0, len(bucket)-1)
#   File "/home/myuser/RayMasteryCheckpoint/qs.py", line 35, in quickSort
#     quickSort(array, low, pi - 1)
#   File "/home/myuser/RayMasteryCheckpoint/qs.py", line 35, in quickSort
#     quickSort(array, low, pi - 1)
#   File "/home/myuser/RayMasteryCheckpoint/qs.py", line 35, in quickSort
#     quickSort(array, low, pi - 1)
#   [Previous line repeated 990 more times]
#   File "/home/myuser/RayMasteryCheckpoint/qs.py", line 32, in quickSort
#     pi = partition(array, low, high)
#   File "/home/myuser/RayMasteryCheckpoint/qs.py", line 13, in partition
#     for j in range(low, high):
# RecursionError: maximum recursion depth exceeded in comparison
# 2023-11-14 00:46:02,691	ERROR worker.py:405 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): ray::call_qs() (pid=1529329, ip=172.17.0.37)
#   File "/home/myuser/RayMasteryCheckpoint/SampleSort.py", line 51, in call_qs
#     return qs.quickSort(bucket, 0, len(bucket)-1)
#   File "/home/myuser/RayMasteryCheckpoint/qs.py", line 35, in quickSort
#     quickSort(array, low, pi - 1)
#   File "/home/myuser/RayMasteryCheckpoint/qs.py", line 35, in quickSort
#     quickSort(array, low, pi - 1)
#   File "/home/myuser/RayMasteryCheckpoint/qs.py", line 35, in quickSort
#     quickSort(array, low, pi - 1)
#   [Previous line repeated 990 more times]
#   File "/home/myuser/RayMasteryCheckpoint/qs.py", line 32, in quickSort
#     pi = partition(array, low, high)
#   File "/home/myuser/RayMasteryCheckpoint/qs.py", line 13, in partition
#     for j in range(low, high):
# RecursionError: maximum recursion depth exceeded in comparison
# 2023-11-14 00:46:06,667	ERROR worker.py:405 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): ray::call_qs() (pid=1529331, ip=172.17.0.37)
#   File "/home/myuser/RayMasteryCheckpoint/SampleSort.py", line 51, in call_qs
#     return qs.quickSort(bucket, 0, len(bucket)-1)
#   File "/home/myuser/RayMasteryCheckpoint/qs.py", line 35, in quickSort
#     quickSort(array, low, pi - 1)
#   File "/home/myuser/RayMasteryCheckpoint/qs.py", line 35, in quickSort
#     quickSort(array, low, pi - 1)
#   File "/home/myuser/RayMasteryCheckpoint/qs.py", line 35, in quickSort
#     quickSort(array, low, pi - 1)
#   [Previous line repeated 990 more times]
#   File "/home/myuser/RayMasteryCheckpoint/qs.py", line 32, in quickSort
#     pi = partition(array, low, high)
#   File "/home/myuser/RayMasteryCheckpoint/qs.py", line 13, in partition
#     for j in range(low, high):
# RecursionError: maximum recursion depth exceeded in comparison
# 2023-11-14 00:46:06,695	ERROR worker.py:405 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): ray::call_qs() (pid=1529330, ip=172.17.0.37)
#   File "/home/myuser/RayMasteryCheckpoint/SampleSort.py", line 51, in call_qs
#     return qs.quickSort(bucket, 0, len(bucket)-1)
#   File "/home/myuser/RayMasteryCheckpoint/qs.py", line 35, in quickSort
#     quickSort(array, low, pi - 1)
#   File "/home/myuser/RayMasteryCheckpoint/qs.py", line 35, in quickSort
#     quickSort(array, low, pi - 1)
#   File "/home/myuser/RayMasteryCheckpoint/qs.py", line 35, in quickSort
#     quickSort(array, low, pi - 1)
#   [Previous line repeated 990 more times]
#   File "/home/myuser/RayMasteryCheckpoint/qs.py", line 32, in quickSort
#     pi = partition(array, low, high)
#   File "/home/myuser/RayMasteryCheckpoint/qs.py", line 13, in partition
#     for j in range(low, high):
# RecursionError: maximum recursion depth exceeded in comparison
# 2023-11-14 00:46:07,667	ERROR worker.py:405 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): ray::call_qs() (pid=1529338, ip=172.17.0.37)
#   File "/home/myuser/RayMasteryCheckpoint/SampleSort.py", line 51, in call_qs
#     return qs.quickSort(bucket, 0, len(bucket)-1)
#   File "/home/myuser/RayMasteryCheckpoint/qs.py", line 35, in quickSort
#     quickSort(array, low, pi - 1)
#   File "/home/myuser/RayMasteryCheckpoint/qs.py", line 35, in quickSort
#     quickSort(array, low, pi - 1)
#   File "/home/myuser/RayMasteryCheckpoint/qs.py", line 35, in quickSort
#     quickSort(array, low, pi - 1)
#   [Previous line repeated 990 more times]
#   File "/home/myuser/RayMasteryCheckpoint/qs.py", line 32, in quickSort
#     pi = partition(array, low, high)
#   File "/home/myuser/RayMasteryCheckpoint/qs.py", line 13, in partition
#     for j in range(low, high):
# RecursionError: maximum recursion depth exceeded in comparison
# 2023-11-14 00:46:07,696	ERROR worker.py:405 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): ray::call_qs() (pid=1529341, ip=172.17.0.37)
#   File "/home/myuser/RayMasteryCheckpoint/SampleSort.py", line 51, in call_qs
#     return qs.quickSort(bucket, 0, len(bucket)-1)
#   File "/home/myuser/RayMasteryCheckpoint/qs.py", line 35, in quickSort
#     quickSort(array, low, pi - 1)
#   File "/home/myuser/RayMasteryCheckpoint/qs.py", line 35, in quickSort
#     quickSort(array, low, pi - 1)
#   File "/home/myuser/RayMasteryCheckpoint/qs.py", line 35, in quickSort
#     quickSort(array, low, pi - 1)
#   [Previous line repeated 990 more times]
#   File "/home/myuser/RayMasteryCheckpoint/qs.py", line 32, in quickSort
#     pi = partition(array, low, high)
#   File "/home/myuser/RayMasteryCheckpoint/qs.py", line 13, in partition
#     for j in range(low, high):
# RecursionError: maximum recursion depth exceeded in comparison
# 2023-11-14 00:46:07,708	ERROR worker.py:405 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): ray::call_qs() (pid=1529301, ip=172.17.0.37)
#   File "/home/myuser/RayMasteryCheckpoint/SampleSort.py", line 51, in call_qs
#     return qs.quickSort(bucket, 0, len(bucket)-1)
#   File "/home/myuser/RayMasteryCheckpoint/qs.py", line 35, in quickSort
#     quickSort(array, low, pi - 1)
#   File "/home/myuser/RayMasteryCheckpoint/qs.py", line 35, in quickSort
#     quickSort(array, low, pi - 1)
#   File "/home/myuser/RayMasteryCheckpoint/qs.py", line 35, in quickSort
#     quickSort(array, low, pi - 1)
#   [Previous line repeated 990 more times]
#   File "/home/myuser/RayMasteryCheckpoint/qs.py", line 32, in quickSort
#     pi = partition(array, low, high)
#   File "/home/myuser/RayMasteryCheckpoint/qs.py", line 13, in partition
#     for j in range(low, high):
# RecursionError: maximum recursion depth exceeded in comparison
# 2023-11-14 00:46:11,184	ERROR worker.py:405 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): ray::call_qs() (pid=1529338, ip=172.17.0.37)
#   File "/home/myuser/RayMasteryCheckpoint/SampleSort.py", line 51, in call_qs
#     return qs.quickSort(bucket, 0, len(bucket)-1)
#   File "/home/myuser/RayMasteryCheckpoint/qs.py", line 35, in quickSort
#     quickSort(array, low, pi - 1)
#   File "/home/myuser/RayMasteryCheckpoint/qs.py", line 35, in quickSort
#     quickSort(array, low, pi - 1)
#   File "/home/myuser/RayMasteryCheckpoint/qs.py", line 35, in quickSort
#     quickSort(array, low, pi - 1)
#   [Previous line repeated 990 more times]
#   File "/home/myuser/RayMasteryCheckpoint/qs.py", line 32, in quickSort
#     pi = partition(array, low, high)
#   File "/home/myuser/RayMasteryCheckpoint/qs.py", line 13, in partition
#     for j in range(low, high):
# RecursionError: maximum recursion depth exceeded in comparison
# 2023-11-14 00:46:11,198	ERROR worker.py:405 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): ray::call_qs() (pid=1529325, ip=172.17.0.37)
#   File "/home/myuser/RayMasteryCheckpoint/SampleSort.py", line 51, in call_qs
#     return qs.quickSort(bucket, 0, len(bucket)-1)
#   File "/home/myuser/RayMasteryCheckpoint/qs.py", line 35, in quickSort
#     quickSort(array, low, pi - 1)
#   File "/home/myuser/RayMasteryCheckpoint/qs.py", line 35, in quickSort
#     quickSort(array, low, pi - 1)
#   File "/home/myuser/RayMasteryCheckpoint/qs.py", line 35, in quickSort
#     quickSort(array, low, pi - 1)
#   [Previous line repeated 990 more times]
#   File "/home/myuser/RayMasteryCheckpoint/qs.py", line 32, in quickSort
#     pi = partition(array, low, high)
#   File "/home/myuser/RayMasteryCheckpoint/qs.py", line 13, in partition
#     for j in range(low, high):
# RecursionError: maximum recursion depth exceeded in comparison
# 2023-11-14 00:46:12,184	ERROR worker.py:405 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): ray::call_qs() (pid=1529335, ip=172.17.0.37)
#   File "/home/myuser/RayMasteryCheckpoint/SampleSort.py", line 51, in call_qs
#     return qs.quickSort(bucket, 0, len(bucket)-1)
#   File "/home/myuser/RayMasteryCheckpoint/qs.py", line 35, in quickSort
#     quickSort(array, low, pi - 1)
#   File "/home/myuser/RayMasteryCheckpoint/qs.py", line 35, in quickSort
#     quickSort(array, low, pi - 1)
#   File "/home/myuser/RayMasteryCheckpoint/qs.py", line 35, in quickSort
#     quickSort(array, low, pi - 1)
#   [Previous line repeated 990 more times]
#   File "/home/myuser/RayMasteryCheckpoint/qs.py", line 32, in quickSort
#     pi = partition(array, low, high)
#   File "/home/myuser/RayMasteryCheckpoint/qs.py", line 13, in partition
#     for j in range(low, high):
# RecursionError: maximum recursion depth exceeded in comparison
# 2023-11-14 00:46:12,196	ERROR worker.py:405 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): ray::call_qs() (pid=1529336, ip=172.17.0.37)
#   File "/home/myuser/RayMasteryCheckpoint/SampleSort.py", line 51, in call_qs
#     return qs.quickSort(bucket, 0, len(bucket)-1)
#   File "/home/myuser/RayMasteryCheckpoint/qs.py", line 35, in quickSort
#     quickSort(array, low, pi - 1)
#   File "/home/myuser/RayMasteryCheckpoint/qs.py", line 35, in quickSort
#     quickSort(array, low, pi - 1)
#   File "/home/myuser/RayMasteryCheckpoint/qs.py", line 35, in quickSort
#     quickSort(array, low, pi - 1)
#   [Previous line repeated 990 more times]
#   File "/home/myuser/RayMasteryCheckpoint/qs.py", line 32, in quickSort
#     pi = partition(array, low, high)
#   File "/home/myuser/RayMasteryCheckpoint/qs.py", line 13, in partition
#     for j in range(low, high):
# RecursionError: maximum recursion depth exceeded in comparison
# 2023-11-14 00:46:12,202	ERROR worker.py:405 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): ray::call_qs() (pid=1529322, ip=172.17.0.37)
#   File "/home/myuser/RayMasteryCheckpoint/SampleSort.py", line 51, in call_qs
#     return qs.quickSort(bucket, 0, len(bucket)-1)
#   File "/home/myuser/RayMasteryCheckpoint/qs.py", line 35, in quickSort
#     quickSort(array, low, pi - 1)
#   File "/home/myuser/RayMasteryCheckpoint/qs.py", line 35, in quickSort
#     quickSort(array, low, pi - 1)
#   File "/home/myuser/RayMasteryCheckpoint/qs.py", line 35, in quickSort
#     quickSort(array, low, pi - 1)
#   [Previous line repeated 990 more times]
#   File "/home/myuser/RayMasteryCheckpoint/qs.py", line 32, in quickSort
#     pi = partition(array, low, high)
#   File "/home/myuser/RayMasteryCheckpoint/qs.py", line 13, in partition
#     for j in range(low, high):
# RecursionError: maximum recursion depth exceeded in comparison
# 2023-11-14 00:46:12,219	ERROR worker.py:405 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): ray::call_qs() (pid=1529321, ip=172.17.0.37)
#   File "/home/myuser/RayMasteryCheckpoint/SampleSort.py", line 51, in call_qs
#     return qs.quickSort(bucket, 0, len(bucket)-1)
#   File "/home/myuser/RayMasteryCheckpoint/qs.py", line 35, in quickSort
#     quickSort(array, low, pi - 1)
#   File "/home/myuser/RayMasteryCheckpoint/qs.py", line 35, in quickSort
#     quickSort(array, low, pi - 1)
#   File "/home/myuser/RayMasteryCheckpoint/qs.py", line 35, in quickSort
#     quickSort(array, low, pi - 1)
#   [Previous line repeated 990 more times]
#   File "/home/myuser/RayMasteryCheckpoint/qs.py", line 32, in quickSort
#     pi = partition(array, low, high)
#   File "/home/myuser/RayMasteryCheckpoint/qs.py", line 13, in partition
#     for j in range(low, high):
# RecursionError: maximum recursion depth exceeded in comparison
# 2023-11-14 00:46:19,200	ERROR worker.py:405 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): ray::call_qs() (pid=1529324, ip=172.17.0.37)
#   File "/home/myuser/RayMasteryCheckpoint/SampleSort.py", line 51, in call_qs
#     return qs.quickSort(bucket, 0, len(bucket)-1)
#   File "/home/myuser/RayMasteryCheckpoint/qs.py", line 35, in quickSort
#     quickSort(array, low, pi - 1)
#   File "/home/myuser/RayMasteryCheckpoint/qs.py", line 35, in quickSort
#     quickSort(array, low, pi - 1)
#   File "/home/myuser/RayMasteryCheckpoint/qs.py", line 35, in quickSort
#     quickSort(array, low, pi - 1)
#   [Previous line repeated 990 more times]
#   File "/home/myuser/RayMasteryCheckpoint/qs.py", line 32, in quickSort
#     pi = partition(array, low, high)
#   File "/home/myuser/RayMasteryCheckpoint/qs.py", line 13, in partition
#     for j in range(low, high):
# RecursionError: maximum recursion depth exceeded in comparison
# 2023-11-14 00:46:20,201	ERROR worker.py:405 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): ray::call_qs() (pid=1529333, ip=172.17.0.37)
#   File "/home/myuser/RayMasteryCheckpoint/SampleSort.py", line 51, in call_qs
#     return qs.quickSort(bucket, 0, len(bucket)-1)
#   File "/home/myuser/RayMasteryCheckpoint/qs.py", line 35, in quickSort
#     quickSort(array, low, pi - 1)
#   File "/home/myuser/RayMasteryCheckpoint/qs.py", line 35, in quickSort
#     quickSort(array, low, pi - 1)
#   File "/home/myuser/RayMasteryCheckpoint/qs.py", line 35, in quickSort
#     quickSort(array, low, pi - 1)
#   [Previous line repeated 990 more times]
#   File "/home/myuser/RayMasteryCheckpoint/qs.py", line 32, in quickSort
#     pi = partition(array, low, high)
#   File "/home/myuser/RayMasteryCheckpoint/qs.py", line 13, in partition
#     for j in range(low, high):
# RecursionError: maximum recursion depth exceeded in comparison
# 2023-11-14 00:46:20,220	ERROR worker.py:405 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): ray::call_qs() (pid=1529342, ip=172.17.0.37)
#   File "/home/myuser/RayMasteryCheckpoint/SampleSort.py", line 51, in call_qs
#     return qs.quickSort(bucket, 0, len(bucket)-1)
#   File "/home/myuser/RayMasteryCheckpoint/qs.py", line 35, in quickSort
#     quickSort(array, low, pi - 1)
#   File "/home/myuser/RayMasteryCheckpoint/qs.py", line 35, in quickSort
#     quickSort(array, low, pi - 1)
#   File "/home/myuser/RayMasteryCheckpoint/qs.py", line 35, in quickSort
#     quickSort(array, low, pi - 1)
#   [Previous line repeated 990 more times]
#   File "/home/myuser/RayMasteryCheckpoint/qs.py", line 32, in quickSort
#     pi = partition(array, low, high)
#   File "/home/myuser/RayMasteryCheckpoint/qs.py", line 13, in partition
#     for j in range(low, high):
# RecursionError: maximum recursion depth exceeded in comparison
# 2023-11-14 00:46:21,201	ERROR worker.py:405 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): ray::call_qs() (pid=1529308, ip=172.17.0.37)
#   File "/home/myuser/RayMasteryCheckpoint/SampleSort.py", line 51, in call_qs
#     return qs.quickSort(bucket, 0, len(bucket)-1)
#   File "/home/myuser/RayMasteryCheckpoint/qs.py", line 35, in quickSort
#     quickSort(array, low, pi - 1)
#   File "/home/myuser/RayMasteryCheckpoint/qs.py", line 35, in quickSort
#     quickSort(array, low, pi - 1)
#   File "/home/myuser/RayMasteryCheckpoint/qs.py", line 35, in quickSort
#     quickSort(array, low, pi - 1)
#   [Previous line repeated 990 more times]
#   File "/home/myuser/RayMasteryCheckpoint/qs.py", line 32, in quickSort
#     pi = partition(array, low, high)
#   File "/home/myuser/RayMasteryCheckpoint/qs.py", line 13, in partition
#     for j in range(low, high):
# RecursionError: maximum recursion depth exceeded in comparison
# 2023-11-14 00:46:23,202	ERROR worker.py:405 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): ray::call_qs() (pid=1529327, ip=172.17.0.37)
#   File "/home/myuser/RayMasteryCheckpoint/SampleSort.py", line 51, in call_qs
#     return qs.quickSort(bucket, 0, len(bucket)-1)
#   File "/home/myuser/RayMasteryCheckpoint/qs.py", line 35, in quickSort
#     quickSort(array, low, pi - 1)
#   File "/home/myuser/RayMasteryCheckpoint/qs.py", line 35, in quickSort
#     quickSort(array, low, pi - 1)
#   File "/home/myuser/RayMasteryCheckpoint/qs.py", line 35, in quickSort
#     quickSort(array, low, pi - 1)
#   [Previous line repeated 990 more times]
#   File "/home/myuser/RayMasteryCheckpoint/qs.py", line 32, in quickSort
#     pi = partition(array, low, high)
#   File "/home/myuser/RayMasteryCheckpoint/qs.py", line 13, in partition
#     for j in range(low, high):
# RecursionError: maximum recursion depth exceeded in comparison
# 2023-11-14 00:46:23,224	ERROR worker.py:405 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): ray::call_qs() (pid=1529336, ip=172.17.0.37)
#   File "/home/myuser/RayMasteryCheckpoint/SampleSort.py", line 51, in call_qs
#     return qs.quickSort(bucket, 0, len(bucket)-1)
#   File "/home/myuser/RayMasteryCheckpoint/qs.py", line 35, in quickSort
#     quickSort(array, low, pi - 1)
#   File "/home/myuser/RayMasteryCheckpoint/qs.py", line 35, in quickSort
#     quickSort(array, low, pi - 1)
#   File "/home/myuser/RayMasteryCheckpoint/qs.py", line 35, in quickSort
#     quickSort(array, low, pi - 1)
#   [Previous line repeated 990 more times]
#   File "/home/myuser/RayMasteryCheckpoint/qs.py", line 32, in quickSort
#     pi = partition(array, low, high)
#   File "/home/myuser/RayMasteryCheckpoint/qs.py", line 13, in partition
#     for j in range(low, high):
# RecursionError: maximum recursion depth exceeded in comparison
# 2023-11-14 00:46:23,272	ERROR worker.py:405 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): ray::call_qs() (pid=1529314, ip=172.17.0.37)
#   File "/home/myuser/RayMasteryCheckpoint/SampleSort.py", line 51, in call_qs
#     return qs.quickSort(bucket, 0, len(bucket)-1)
#   File "/home/myuser/RayMasteryCheckpoint/qs.py", line 35, in quickSort
#     quickSort(array, low, pi - 1)
#   File "/home/myuser/RayMasteryCheckpoint/qs.py", line 35, in quickSort
#     quickSort(array, low, pi - 1)
#   File "/home/myuser/RayMasteryCheckpoint/qs.py", line 35, in quickSort
#     quickSort(array, low, pi - 1)
#   [Previous line repeated 990 more times]
#   File "/home/myuser/RayMasteryCheckpoint/qs.py", line 32, in quickSort
#     pi = partition(array, low, high)
#   File "/home/myuser/RayMasteryCheckpoint/qs.py", line 13, in partition
#     for j in range(low, high):
# RecursionError: maximum recursion depth exceeded in comparison
# 2023-11-14 00:46:24,273	ERROR worker.py:405 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): ray::call_qs() (pid=1529322, ip=172.17.0.37)
#   File "/home/myuser/RayMasteryCheckpoint/SampleSort.py", line 51, in call_qs
#     return qs.quickSort(bucket, 0, len(bucket)-1)
#   File "/home/myuser/RayMasteryCheckpoint/qs.py", line 35, in quickSort
#     quickSort(array, low, pi - 1)
#   File "/home/myuser/RayMasteryCheckpoint/qs.py", line 35, in quickSort
#     quickSort(array, low, pi - 1)
#   File "/home/myuser/RayMasteryCheckpoint/qs.py", line 35, in quickSort
#     quickSort(array, low, pi - 1)
#   [Previous line repeated 990 more times]
#   File "/home/myuser/RayMasteryCheckpoint/qs.py", line 32, in quickSort
#     pi = partition(array, low, high)
#   File "/home/myuser/RayMasteryCheckpoint/qs.py", line 13, in partition
#     for j in range(low, high):
# RecursionError: maximum recursion depth exceeded in comparison
# 2023-11-14 00:46:24,302	ERROR worker.py:405 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): ray::call_qs() (pid=1529328, ip=172.17.0.37)
#   File "/home/myuser/RayMasteryCheckpoint/SampleSort.py", line 51, in call_qs
#     return qs.quickSort(bucket, 0, len(bucket)-1)
#   File "/home/myuser/RayMasteryCheckpoint/qs.py", line 35, in quickSort
#     quickSort(array, low, pi - 1)
#   File "/home/myuser/RayMasteryCheckpoint/qs.py", line 35, in quickSort
#     quickSort(array, low, pi - 1)
#   File "/home/myuser/RayMasteryCheckpoint/qs.py", line 35, in quickSort
#     quickSort(array, low, pi - 1)
#   [Previous line repeated 990 more times]
#   File "/home/myuser/RayMasteryCheckpoint/qs.py", line 32, in quickSort
#     pi = partition(array, low, high)
#   File "/home/myuser/RayMasteryCheckpoint/qs.py", line 13, in partition
#     for j in range(low, high):
# RecursionError: maximum recursion depth exceeded in comparison
# 2023-11-14 00:46:26,207	ERROR worker.py:405 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): ray::call_qs() (pid=1529338, ip=172.17.0.37)
#   File "/home/myuser/RayMasteryCheckpoint/SampleSort.py", line 51, in call_qs
#     return qs.quickSort(bucket, 0, len(bucket)-1)
#   File "/home/myuser/RayMasteryCheckpoint/qs.py", line 35, in quickSort
#     quickSort(array, low, pi - 1)
#   File "/home/myuser/RayMasteryCheckpoint/qs.py", line 35, in quickSort
#     quickSort(array, low, pi - 1)
#   File "/home/myuser/RayMasteryCheckpoint/qs.py", line 35, in quickSort
#     quickSort(array, low, pi - 1)
#   [Previous line repeated 990 more times]
#   File "/home/myuser/RayMasteryCheckpoint/qs.py", line 32, in quickSort
#     pi = partition(array, low, high)
#   File "/home/myuser/RayMasteryCheckpoint/qs.py", line 13, in partition
#     for j in range(low, high):
# RecursionError: maximum recursion depth exceeded in comparison
# 2023-11-14 00:46:27,207	ERROR worker.py:405 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): ray::call_qs() (pid=1529327, ip=172.17.0.37)
#   File "/home/myuser/RayMasteryCheckpoint/SampleSort.py", line 51, in call_qs
#     return qs.quickSort(bucket, 0, len(bucket)-1)
#   File "/home/myuser/RayMasteryCheckpoint/qs.py", line 35, in quickSort
#     quickSort(array, low, pi - 1)
#   File "/home/myuser/RayMasteryCheckpoint/qs.py", line 35, in quickSort
#     quickSort(array, low, pi - 1)
#   File "/home/myuser/RayMasteryCheckpoint/qs.py", line 35, in quickSort
#     quickSort(array, low, pi - 1)
#   [Previous line repeated 990 more times]
#   File "/home/myuser/RayMasteryCheckpoint/qs.py", line 32, in quickSort
#     pi = partition(array, low, high)
#   File "/home/myuser/RayMasteryCheckpoint/qs.py", line 13, in partition
#     for j in range(low, high):
# RecursionError: maximum recursion depth exceeded in comparison
# ---------------------------------------------------------------------------
# RayTaskError(RecursionError)              Traceback (most recent call last)
# File <timed exec>:2
#
# File ~/RayMasteryCheckpoint/SampleSort.py:44, in sampleSort(arr, total_buckets)
#      41     print(len(bucket))
#      43 # Step 3: Sort each bucket in parallel
# ---> 44 sorted_buckets = ray.get([call_qs.remote(bucket) for bucket in buckets])
#      46 # Step 4: Concatenate the results
#      47 return [element for bucket in sorted_buckets for element in bucket]
#
# File ~/.local/lib/python3.10/site-packages/ray/_private/auto_init_hook.py:24, in wrap_auto_init.<locals>.auto_init_wrapper(*args, **kwargs)
#      21 @wraps(fn)
#      22 def auto_init_wrapper(*args, **kwargs):
#      23     auto_init_ray()
# ---> 24     return fn(*args, **kwargs)
#
# File ~/.local/lib/python3.10/site-packages/ray/_private/client_mode_hook.py:103, in client_mode_hook.<locals>.wrapper(*args, **kwargs)
#     101     if func.__name__ != "init" or is_client_mode_enabled_by_default:
#     102         return getattr(ray, func.__name__)(*args, **kwargs)
# --> 103 return func(*args, **kwargs)
#
# File ~/.local/lib/python3.10/site-packages/ray/_private/worker.py:2547, in get(object_refs, timeout)
#    2545     worker.core_worker.dump_object_store_memory_usage()
#    2546 if isinstance(value, RayTaskError):
# -> 2547     raise value.as_instanceof_cause()
#    2548 else:
#    2549     raise value
#
# RayTaskError(RecursionError): ray::call_qs() (pid=1529342, ip=172.17.0.37)
#   File "/home/myuser/RayMasteryCheckpoint/SampleSort.py", line 51, in call_qs
#     return qs.quickSort(bucket, 0, len(bucket)-1)
#   File "/home/myuser/RayMasteryCheckpoint/qs.py", line 35, in quickSort
#     quickSort(array, low, pi - 1)
#   File "/home/myuser/RayMasteryCheckpoint/qs.py", line 35, in quickSort
#     quickSort(array, low, pi - 1)
#   File "/home/myuser/RayMasteryCheckpoint/qs.py", line 35, in quickSort
#     quickSort(array, low, pi - 1)
#   [Previous line repeated 990 more times]
#   File "/home/myuser/RayMasteryCheckpoint/qs.py", line 32, in quickSort
#     pi = partition(array, low, high)
#   File "/home/myuser/RayMasteryCheckpoint/qs.py", line 13, in partition
#     for j in range(low, high):
# RecursionError: maximum recursion depth exceeded in comparison
# 2023-11-14 00:46:34,205	ERROR worker.py:405 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): ray::call_qs() (pid=1529312, ip=172.17.0.37)
#   File "/home/myuser/RayMasteryCheckpoint/SampleSort.py", line 51, in call_qs
#     return qs.quickSort(bucket, 0, len(bucket)-1)
#   File "/home/myuser/RayMasteryCheckpoint/qs.py", line 35, in quickSort
#     quickSort(array, low, pi - 1)
#   File "/home/myuser/RayMasteryCheckpoint/qs.py", line 35, in quickSort
#     quickSort(array, low, pi - 1)
#   File "/home/myuser/RayMasteryCheckpoint/qs.py", line 35, in quickSort
#     quickSort(array, low, pi - 1)
#   [Previous line repeated 990 more times]
#   File "/home/myuser/RayMasteryCheckpoint/qs.py", line 32, in quickSort
#     pi = partition(array, low, high)
#   File "/home/myuser/RayMasteryCheckpoint/qs.py", line 13, in partition
#     for j in range(low, high):
# RecursionError: maximum recursion depth exceeded in comparison
# 2023-11-14 00:46:34,208	ERROR worker.py:405 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): ray::call_qs() (pid=1529331, ip=172.17.0.37)
#   File "/home/myuser/RayMasteryCheckpoint/SampleSort.py", line 51, in call_qs
#     return qs.quickSort(bucket, 0, len(bucket)-1)
#   File "/home/myuser/RayMasteryCheckpoint/qs.py", line 35, in quickSort
#     quickSort(array, low, pi - 1)
#   File "/home/myuser/RayMasteryCheckpoint/qs.py", line 35, in quickSort
#     quickSort(array, low, pi - 1)
#   File "/home/myuser/RayMasteryCheckpoint/qs.py", line 35, in quickSort
#     quickSort(array, low, pi - 1)
#   [Previous line repeated 990 more times]
#   File "/home/myuser/RayMasteryCheckpoint/qs.py", line 32, in quickSort
#     pi = partition(array, low, high)
#   File "/home/myuser/RayMasteryCheckpoint/qs.py", line 13, in partition
#     for j in range(low, high):
# RecursionError: maximum recursion depth exceeded in comparison
# 2023-11-14 00:46:35,206	ERROR worker.py:405 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): ray::call_qs() (pid=1529316, ip=172.17.0.37)
#   File "/home/myuser/RayMasteryCheckpoint/SampleSort.py", line 51, in call_qs
#     return qs.quickSort(bucket, 0, len(bucket)-1)
#   File "/home/myuser/RayMasteryCheckpoint/qs.py", line 35, in quickSort
#     quickSort(array, low, pi - 1)
#   File "/home/myuser/RayMasteryCheckpoint/qs.py", line 35, in quickSort
#     quickSort(array, low, pi - 1)
#   File "/home/myuser/RayMasteryCheckpoint/qs.py", line 35, in quickSort
#     quickSort(array, low, pi - 1)
#   [Previous line repeated 990 more times]
#   File "/home/myuser/RayMasteryCheckpoint/qs.py", line 32, in quickSort
#     pi = partition(array, low, high)
#   File "/home/myuser/RayMasteryCheckpoint/qs.py", line 13, in partition
#     for j in range(low, high):
# RecursionError: maximum recursion depth exceeded in comparison
# 2023-11-14 00:46:35,207	ERROR worker.py:405 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): ray::call_qs() (pid=1529329, ip=172.17.0.37)
#   File "/home/myuser/RayMasteryCheckpoint/SampleSort.py", line 51, in call_qs
#     return qs.quickSort(bucket, 0, len(bucket)-1)
#   File "/home/myuser/RayMasteryCheckpoint/qs.py", line 35, in quickSort
#     quickSort(array, low, pi - 1)
#   File "/home/myuser/RayMasteryCheckpoint/qs.py", line 35, in quickSort
#     quickSort(array, low, pi - 1)
#   File "/home/myuser/RayMasteryCheckpoint/qs.py", line 35, in quickSort
#     quickSort(array, low, pi - 1)
#   [Previous line repeated 990 more times]
#   File "/home/myuser/RayMasteryCheckpoint/qs.py", line 32, in quickSort
#     pi = partition(array, low, high)
#   File "/home/myuser/RayMasteryCheckpoint/qs.py", line 13, in partition
#     for j in range(low, high):
# RecursionError: maximum recursion depth exceeded in comparison
# 2023-11-14 00:46:35,208	ERROR worker.py:405 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): ray::call_qs() (pid=1529337, ip=172.17.0.37)
#   File "/home/myuser/RayMasteryCheckpoint/SampleSort.py", line 51, in call_qs
#     return qs.quickSort(bucket, 0, len(bucket)-1)
#   File "/home/myuser/RayMasteryCheckpoint/qs.py", line 35, in quickSort
#     quickSort(array, low, pi - 1)
#   File "/home/myuser/RayMasteryCheckpoint/qs.py", line 35, in quickSort
#     quickSort(array, low, pi - 1)
#   File "/home/myuser/RayMasteryCheckpoint/qs.py", line 35, in quickSort
#     quickSort(array, low, pi - 1)
#   [Previous line repeated 990 more times]
#   File "/home/myuser/RayMasteryCheckpoint/qs.py", line 32, in quickSort
#     pi = partition(array, low, high)
#   File "/home/myuser/RayMasteryCheckpoint/qs.py", line 13, in partition
#     for j in range(low, high):
# RecursionError: maximum recursion depth exceeded in comparison
# 2023-11-14 00:46:37,276	ERROR worker.py:405 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): ray::call_qs() (pid=1529311, ip=172.17.0.37)
#   File "/home/myuser/RayMasteryCheckpoint/SampleSort.py", line 51, in call_qs
#     return qs.quickSort(bucket, 0, len(bucket)-1)
#   File "/home/myuser/RayMasteryCheckpoint/qs.py", line 35, in quickSort
#     quickSort(array, low, pi - 1)
#   File "/home/myuser/RayMasteryCheckpoint/qs.py", line 35, in quickSort
#     quickSort(array, low, pi - 1)
#   File "/home/myuser/RayMasteryCheckpoint/qs.py", line 35, in quickSort
#     quickSort(array, low, pi - 1)
#   [Previous line repeated 990 more times]
#   File "/home/myuser/RayMasteryCheckpoint/qs.py", line 32, in quickSort
#     pi = partition(array, low, high)
#   File "/home/myuser/RayMasteryCheckpoint/qs.py", line 13, in partition
#     for j in range(low, high):
# RecursionError: maximum recursion depth exceeded in comparison
# 2023-11-14 00:46:39,277	ERROR worker.py:405 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): ray::call_qs() (pid=1529325, ip=172.17.0.37)
#   File "/home/myuser/RayMasteryCheckpoint/SampleSort.py", line 51, in call_qs
#     return qs.quickSort(bucket, 0, len(bucket)-1)
#   File "/home/myuser/RayMasteryCheckpoint/qs.py", line 35, in quickSort
#     quickSort(array, low, pi - 1)
#   File "/home/myuser/RayMasteryCheckpoint/qs.py", line 35, in quickSort
#     quickSort(array, low, pi - 1)
#   File "/home/myuser/RayMasteryCheckpoint/qs.py", line 35, in quickSort
#     quickSort(array, low, pi - 1)
#   [Previous line repeated 990 more times]
#   File "/home/myuser/RayMasteryCheckpoint/qs.py", line 32, in quickSort
#     pi = partition(array, low, high)
#   File "/home/myuser/RayMasteryCheckpoint/qs.py", line 13, in partition
#     for j in range(low, high):
# RecursionError: maximum recursion depth exceeded in comparison
# 2023-11-14 00:46:39,279	ERROR worker.py:405 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): ray::call_qs() (pid=1529341, ip=172.17.0.37)
#   File "/home/myuser/RayMasteryCheckpoint/SampleSort.py", line 51, in call_qs
#     return qs.quickSort(bucket, 0, len(bucket)-1)
#   File "/home/myuser/RayMasteryCheckpoint/qs.py", line 35, in quickSort
#     quickSort(array, low, pi - 1)
#   File "/home/myuser/RayMasteryCheckpoint/qs.py", line 35, in quickSort
#     quickSort(array, low, pi - 1)
#   File "/home/myuser/RayMasteryCheckpoint/qs.py", line 35, in quickSort
#     quickSort(array, low, pi - 1)
#   [Previous line repeated 990 more times]
#   File "/home/myuser/RayMasteryCheckpoint/qs.py", line 32, in quickSort
#     pi = partition(array, low, high)
#   File "/home/myuser/RayMasteryCheckpoint/qs.py", line 13, in partition
#     for j in range(low, high):
# RecursionError: maximum recursion depth exceeded in comparison
# 2023-11-14 00:46:41,278	ERROR worker.py:405 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): ray::call_qs() (pid=1529330, ip=172.17.0.37)
#   File "/home/myuser/RayMasteryCheckpoint/SampleSort.py", line 51, in call_qs
#     return qs.quickSort(bucket, 0, len(bucket)-1)
#   File "/home/myuser/RayMasteryCheckpoint/qs.py", line 35, in quickSort
#     quickSort(array, low, pi - 1)
#   File "/home/myuser/RayMasteryCheckpoint/qs.py", line 35, in quickSort
#     quickSort(array, low, pi - 1)
#   File "/home/myuser/RayMasteryCheckpoint/qs.py", line 35, in quickSort
#     quickSort(array, low, pi - 1)
#   [Previous line repeated 990 more times]
#   File "/home/myuser/RayMasteryCheckpoint/qs.py", line 32, in quickSort
#     pi = partition(array, low, high)
#   File "/home/myuser/RayMasteryCheckpoint/qs.py", line 13, in partition
#     for j in range(low, high):
# RecursionError: maximum recursion depth exceeded in comparison
# 2023-11-14 00:46:42,279	ERROR worker.py:405 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): ray::call_qs() (pid=1529327, ip=172.17.0.37)
#   File "/home/myuser/RayMasteryCheckpoint/SampleSort.py", line 51, in call_qs
#     return qs.quickSort(bucket, 0, len(bucket)-1)
#   File "/home/myuser/RayMasteryCheckpoint/qs.py", line 35, in quickSort
#     quickSort(array, low, pi - 1)
#   File "/home/myuser/RayMasteryCheckpoint/qs.py", line 35, in quickSort
#     quickSort(array, low, pi - 1)
#   File "/home/myuser/RayMasteryCheckpoint/qs.py", line 35, in quickSort
#     quickSort(array, low, pi - 1)
#   [Previous line repeated 990 more times]
#   File "/home/myuser/RayMasteryCheckpoint/qs.py", line 32, in quickSort
#     pi = partition(array, low, high)
#   File "/home/myuser/RayMasteryCheckpoint/qs.py", line 13, in partition
#     for j in range(low, high):
# RecursionError: maximum recursion depth exceeded in comparison
# 2023-11-14 00:46:43,279	ERROR worker.py:405 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): ray::call_qs() (pid=1529334, ip=172.17.0.37)
#   File "/home/myuser/RayMasteryCheckpoint/SampleSort.py", line 51, in call_qs
#     return qs.quickSort(bucket, 0, len(bucket)-1)
#   File "/home/myuser/RayMasteryCheckpoint/qs.py", line 35, in quickSort
#     quickSort(array, low, pi - 1)
#   File "/home/myuser/RayMasteryCheckpoint/qs.py", line 35, in quickSort
#     quickSort(array, low, pi - 1)
#   File "/home/myuser/RayMasteryCheckpoint/qs.py", line 35, in quickSort
#     quickSort(array, low, pi - 1)
#   [Previous line repeated 990 more times]
#   File "/home/myuser/RayMasteryCheckpoint/qs.py", line 32, in quickSort
#     pi = partition(array, low, high)
#   File "/home/myuser/RayMasteryCheckpoint/qs.py", line 13, in partition
#     for j in range(low, high):
# RecursionError: maximum recursion depth exceeded in comparison
# 2023-11-14 00:46:43,281	ERROR worker.py:405 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): ray::call_qs() (pid=1529324, ip=172.17.0.37)
#   File "/home/myuser/RayMasteryCheckpoint/SampleSort.py", line 51, in call_qs
#     return qs.quickSort(bucket, 0, len(bucket)-1)
#   File "/home/myuser/RayMasteryCheckpoint/qs.py", line 35, in quickSort
#     quickSort(array, low, pi - 1)
#   File "/home/myuser/RayMasteryCheckpoint/qs.py", line 35, in quickSort
#     quickSort(array, low, pi - 1)
#   File "/home/myuser/RayMasteryCheckpoint/qs.py", line 35, in quickSort
#     quickSort(array, low, pi - 1)
#   [Previous line repeated 990 more times]
#   File "/home/myuser/RayMasteryCheckpoint/qs.py", line 32, in quickSort
#     pi = partition(array, low, high)
#   File "/home/myuser/RayMasteryCheckpoint/qs.py", line 13, in partition
#     for j in range(low, high):
# RecursionError: maximum recursion depth exceeded in comparison
# 2023-11-14 00:46:44,280	ERROR worker.py:405 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): ray::call_qs() (pid=1529314, ip=172.17.0.37)
#   File "/home/myuser/RayMasteryCheckpoint/SampleSort.py", line 51, in call_qs
#     return qs.quickSort(bucket, 0, len(bucket)-1)
#   File "/home/myuser/RayMasteryCheckpoint/qs.py", line 35, in quickSort
#     quickSort(array, low, pi - 1)
#   File "/home/myuser/RayMasteryCheckpoint/qs.py", line 35, in quickSort
#     quickSort(array, low, pi - 1)
#   File "/home/myuser/RayMasteryCheckpoint/qs.py", line 35, in quickSort
#     quickSort(array, low, pi - 1)
#   [Previous line repeated 990 more times]
#   File "/home/myuser/RayMasteryCheckpoint/qs.py", line 32, in quickSort
#     pi = partition(array, low, high)
#   File "/home/myuser/RayMasteryCheckpoint/qs.py", line 13, in partition
#     for j in range(low, high):
# RecursionError: maximum recursion depth exceeded in comparison
# 2023-11-14 00:46:44,282	ERROR worker.py:405 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): ray::call_qs() (pid=1529336, ip=172.17.0.37)
#   File "/home/myuser/RayMasteryCheckpoint/SampleSort.py", line 51, in call_qs
#     return qs.quickSort(bucket, 0, len(bucket)-1)
#   File "/home/myuser/RayMasteryCheckpoint/qs.py", line 35, in quickSort
#     quickSort(array, low, pi - 1)
#   File "/home/myuser/RayMasteryCheckpoint/qs.py", line 35, in quickSort
#     quickSort(array, low, pi - 1)
#   File "/home/myuser/RayMasteryCheckpoint/qs.py", line 35, in quickSort
#     quickSort(array, low, pi - 1)
#   [Previous line repeated 990 more times]
#   File "/home/myuser/RayMasteryCheckpoint/qs.py", line 32, in quickSort
#     pi = partition(array, low, high)
#   File "/home/myuser/RayMasteryCheckpoint/qs.py", line 13, in partition
#     for j in range(low, high):
# RecursionError: maximum recursion depth exceeded in comparison
# 2023-11-14 00:46:44,283	ERROR worker.py:405 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): ray::call_qs() (pid=1529340, ip=172.17.0.37)
#   File "/home/myuser/RayMasteryCheckpoint/SampleSort.py", line 51, in call_qs
#     return qs.quickSort(bucket, 0, len(bucket)-1)
#   File "/home/myuser/RayMasteryCheckpoint/qs.py", line 35, in quickSort
#     quickSort(array, low, pi - 1)
#   File "/home/myuser/RayMasteryCheckpoint/qs.py", line 35, in quickSort
#     quickSort(array, low, pi - 1)
#   File "/home/myuser/RayMasteryCheckpoint/qs.py", line 35, in quickSort
#     quickSort(array, low, pi - 1)
#   [Previous line repeated 990 more times]
#   File "/home/myuser/RayMasteryCheckpoint/qs.py", line 32, in quickSort
#     pi = partition(array, low, high)
#   File "/home/myuser/RayMasteryCheckpoint/qs.py", line 13, in partition
#     for j in range(low, high):
# RecursionError: maximum recursion depth exceeded in comparison
# 2023-11-14 00:46:45,281	ERROR worker.py:405 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): ray::call_qs() (pid=1529308, ip=172.17.0.37)
#   File "/home/myuser/RayMasteryCheckpoint/SampleSort.py", line 51, in call_qs
#     return qs.quickSort(bucket, 0, len(bucket)-1)
#   File "/home/myuser/RayMasteryCheckpoint/qs.py", line 35, in quickSort
#     quickSort(array, low, pi - 1)
#   File "/home/myuser/RayMasteryCheckpoint/qs.py", line 35, in quickSort
#     quickSort(array, low, pi - 1)
#   File "/home/myuser/RayMasteryCheckpoint/qs.py", line 35, in quickSort
#     quickSort(array, low, pi - 1)
#   [Previous line repeated 990 more times]
#   File "/home/myuser/RayMasteryCheckpoint/qs.py", line 32, in quickSort
#     pi = partition(array, low, high)
#   File "/home/myuser/RayMasteryCheckpoint/qs.py", line 13, in partition
#     for j in range(low, high):
# RecursionError: maximum recursion depth exceeded in comparison
# 2023-11-14 00:46:48,283	ERROR worker.py:405 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): ray::call_qs() (pid=1529322, ip=172.17.0.37)
#   File "/home/myuser/RayMasteryCheckpoint/SampleSort.py", line 51, in call_qs
#     return qs.quickSort(bucket, 0, len(bucket)-1)
#   File "/home/myuser/RayMasteryCheckpoint/qs.py", line 35, in quickSort
#     quickSort(array, low, pi - 1)
#   File "/home/myuser/RayMasteryCheckpoint/qs.py", line 35, in quickSort
#     quickSort(array, low, pi - 1)
#   File "/home/myuser/RayMasteryCheckpoint/qs.py", line 35, in quickSort
#     quickSort(array, low, pi - 1)
#   [Previous line repeated 990 more times]
#   File "/home/myuser/RayMasteryCheckpoint/qs.py", line 32, in quickSort
#     pi = partition(array, low, high)
#   File "/home/myuser/RayMasteryCheckpoint/qs.py", line 13, in partition
#     for j in range(low, high):
# RecursionError: maximum recursion depth exceeded in comparison
# 2023-11-14 00:46:51,285	ERROR worker.py:405 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): ray::call_qs() (pid=1529317, ip=172.17.0.37)
#   File "/home/myuser/RayMasteryCheckpoint/SampleSort.py", line 51, in call_qs
#     return qs.quickSort(bucket, 0, len(bucket)-1)
#   File "/home/myuser/RayMasteryCheckpoint/qs.py", line 35, in quickSort
#     quickSort(array, low, pi - 1)
#   File "/home/myuser/RayMasteryCheckpoint/qs.py", line 35, in quickSort
#     quickSort(array, low, pi - 1)
#   File "/home/myuser/RayMasteryCheckpoint/qs.py", line 35, in quickSort
#     quickSort(array, low, pi - 1)
#   [Previous line repeated 990 more times]
#   File "/home/myuser/RayMasteryCheckpoint/qs.py", line 32, in quickSort
#     pi = partition(array, low, high)
#   File "/home/myuser/RayMasteryCheckpoint/qs.py", line 13, in partition
#     for j in range(low, high):
# RecursionError: maximum recursion depth exceeded in comparison
# 2023-11-14 00:46:52,285	ERROR worker.py:405 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): ray::call_qs() (pid=1529339, ip=172.17.0.37)
#   File "/home/myuser/RayMasteryCheckpoint/SampleSort.py", line 51, in call_qs
#     return qs.quickSort(bucket, 0, len(bucket)-1)
#   File "/home/myuser/RayMasteryCheckpoint/qs.py", line 35, in quickSort
#     quickSort(array, low, pi - 1)
#   File "/home/myuser/RayMasteryCheckpoint/qs.py", line 35, in quickSort
#     quickSort(array, low, pi - 1)
#   File "/home/myuser/RayMasteryCheckpoint/qs.py", line 35, in quickSort
#     quickSort(array, low, pi - 1)
#   [Previous line repeated 990 more times]
#   File "/home/myuser/RayMasteryCheckpoint/qs.py", line 32, in quickSort
#     pi = partition(array, low, high)
#   File "/home/myuser/RayMasteryCheckpoint/qs.py", line 13, in partition
#     for j in range(low, high):
# RecursionError: maximum recursion depth exceeded in comparison
# 2023-11-14 00:46:54,286	ERROR worker.py:405 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): ray::call_qs() (pid=1529338, ip=172.17.0.37)
#   File "/home/myuser/RayMasteryCheckpoint/SampleSort.py", line 51, in call_qs
#     return qs.quickSort(bucket, 0, len(bucket)-1)
#   File "/home/myuser/RayMasteryCheckpoint/qs.py", line 35, in quickSort
#     quickSort(array, low, pi - 1)
#   File "/home/myuser/RayMasteryCheckpoint/qs.py", line 35, in quickSort
#     quickSort(array, low, pi - 1)
#   File "/home/myuser/RayMasteryCheckpoint/qs.py", line 35, in quickSort
#     quickSort(array, low, pi - 1)
#   [Previous line repeated 990 more times]
#   File "/home/myuser/RayMasteryCheckpoint/qs.py", line 32, in quickSort
#     pi = partition(array, low, high)
#   File "/home/myuser/RayMasteryCheckpoint/qs.py", line 13, in partition
#     for j in range(low, high):
# RecursionError: maximum recursion depth exceeded in comparison
# 2023-11-14 00:46:56,377	ERROR worker.py:405 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): ray::call_qs() (pid=1529335, ip=172.17.0.37)
#   File "/home/myuser/RayMasteryCheckpoint/SampleSort.py", line 51, in call_qs
#     return qs.quickSort(bucket, 0, len(bucket)-1)
#   File "/home/myuser/RayMasteryCheckpoint/qs.py", line 35, in quickSort
#     quickSort(array, low, pi - 1)
#   File "/home/myuser/RayMasteryCheckpoint/qs.py", line 35, in quickSort
#     quickSort(array, low, pi - 1)
#   File "/home/myuser/RayMasteryCheckpoint/qs.py", line 35, in quickSort
#     quickSort(array, low, pi - 1)
#   [Previous line repeated 990 more times]
#   File "/home/myuser/RayMasteryCheckpoint/qs.py", line 32, in quickSort
#     pi = partition(array, low, high)
#   File "/home/myuser/RayMasteryCheckpoint/qs.py", line 13, in partition
#     for j in range(low, high):
# RecursionError: maximum recursion depth exceeded in comparison
# 2023-11-14 00:46:57,378	ERROR worker.py:405 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): ray::call_qs() (pid=1529328, ip=172.17.0.37)
#   File "/home/myuser/RayMasteryCheckpoint/SampleSort.py", line 51, in call_qs
#     return qs.quickSort(bucket, 0, len(bucket)-1)
#   File "/home/myuser/RayMasteryCheckpoint/qs.py", line 35, in quickSort
#     quickSort(array, low, pi - 1)
#   File "/home/myuser/RayMasteryCheckpoint/qs.py", line 35, in quickSort
#     quickSort(array, low, pi - 1)
#   File "/home/myuser/RayMasteryCheckpoint/qs.py", line 35, in quickSort
#     quickSort(array, low, pi - 1)
#   [Previous line repeated 990 more times]
#   File "/home/myuser/RayMasteryCheckpoint/qs.py", line 32, in quickSort
#     pi = partition(array, low, high)
#   File "/home/myuser/RayMasteryCheckpoint/qs.py", line 13, in partition
#     for j in range(low, high):
# RecursionError: maximum recursion depth exceeded in comparison
# 2023-11-14 00:47:02,382	ERROR worker.py:405 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): ray::call_qs() (pid=1529320, ip=172.17.0.37)
#   File "/home/myuser/RayMasteryCheckpoint/SampleSort.py", line 51, in call_qs
#     return qs.quickSort(bucket, 0, len(bucket)-1)
#   File "/home/myuser/RayMasteryCheckpoint/qs.py", line 35, in quickSort
#     quickSort(array, low, pi - 1)
#   File "/home/myuser/RayMasteryCheckpoint/qs.py", line 35, in quickSort
#     quickSort(array, low, pi - 1)
#   File "/home/myuser/RayMasteryCheckpoint/qs.py", line 35, in quickSort
#     quickSort(array, low, pi - 1)
#   [Previous line repeated 990 more times]
#   File "/home/myuser/RayMasteryCheckpoint/qs.py", line 32, in quickSort
#     pi = partition(array, low, high)
#   File "/home/myuser/RayMasteryCheckpoint/qs.py", line 13, in partition
#     for j in range(low, high):
# RecursionError: maximum recursion depth exceeded in comparison
# 2023-11-14 00:47:04,383	ERROR worker.py:405 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): ray::call_qs() (pid=1529326, ip=172.17.0.37)
#   File "/home/myuser/RayMasteryCheckpoint/SampleSort.py", line 51, in call_qs
#     return qs.quickSort(bucket, 0, len(bucket)-1)
#   File "/home/myuser/RayMasteryCheckpoint/qs.py", line 35, in quickSort
#     quickSort(array, low, pi - 1)
#   File "/home/myuser/RayMasteryCheckpoint/qs.py", line 35, in quickSort
#     quickSort(array, low, pi - 1)
#   File "/home/myuser/RayMasteryCheckpoint/qs.py", line 35, in quickSort
#     quickSort(array, low, pi - 1)
#   [Previous line repeated 990 more times]
#   File "/home/myuser/RayMasteryCheckpoint/qs.py", line 32, in quickSort
#     pi = partition(array, low, high)
#   File "/home/myuser/RayMasteryCheckpoint/qs.py", line 13, in partition
#     for j in range(low, high):
# RecursionError: maximum recursion depth exceeded in comparison
# 2023-11-14 00:47:06,385	ERROR worker.py:405 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): ray::call_qs() (pid=1529321, ip=172.17.0.37)
#   File "/home/myuser/RayMasteryCheckpoint/SampleSort.py", line 51, in call_qs
#     return qs.quickSort(bucket, 0, len(bucket)-1)
#   File "/home/myuser/RayMasteryCheckpoint/qs.py", line 35, in quickSort
#     quickSort(array, low, pi - 1)
#   File "/home/myuser/RayMasteryCheckpoint/qs.py", line 35, in quickSort
#     quickSort(array, low, pi - 1)
#   File "/home/myuser/RayMasteryCheckpoint/qs.py", line 35, in quickSort
#     quickSort(array, low, pi - 1)
#   [Previous line repeated 990 more times]
#   File "/home/myuser/RayMasteryCheckpoint/qs.py", line 32, in quickSort
#     pi = partition(array, low, high)
#   File "/home/myuser/RayMasteryCheckpoint/qs.py", line 13, in partition
#     for j in range(low, high):
# RecursionError: maximum recursion depth exceeded in comparison
# 2023-11-14 00:47:10,388	ERROR worker.py:405 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): ray::call_qs() (pid=1529301, ip=172.17.0.37)
#   File "/home/myuser/RayMasteryCheckpoint/SampleSort.py", line 51, in call_qs
#     return qs.quickSort(bucket, 0, len(bucket)-1)
#   File "/home/myuser/RayMasteryCheckpoint/qs.py", line 35, in quickSort
#     quickSort(array, low, pi - 1)
#   File "/home/myuser/RayMasteryCheckpoint/qs.py", line 35, in quickSort
#     quickSort(array, low, pi - 1)
#   File "/home/myuser/RayMasteryCheckpoint/qs.py", line 35, in quickSort
#     quickSort(array, low, pi - 1)
#   [Previous line repeated 990 more times]
#   File "/home/myuser/RayMasteryCheckpoint/qs.py", line 32, in quickSort
#     pi = partition(array, low, high)
#   File "/home/myuser/RayMasteryCheckpoint/qs.py", line 13, in partition
#     for j in range(low, high):
# RecursionError: maximum recursion depth exceeded in comparison
# 2023-11-14 00:47:20,396	ERROR worker.py:405 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): ray::call_qs() (pid=1529333, ip=172.17.0.37)
#   File "/home/myuser/RayMasteryCheckpoint/SampleSort.py", line 51, in call_qs
#     return qs.quickSort(bucket, 0, len(bucket)-1)
#   File "/home/myuser/RayMasteryCheckpoint/qs.py", line 35, in quickSort
#     quickSort(array, low, pi - 1)
#   File "/home/myuser/RayMasteryCheckpoint/qs.py", line 35, in quickSort
#     quickSort(array, low, pi - 1)
#   File "/home/myuser/RayMasteryCheckpoint/qs.py", line 35, in quickSort
#     quickSort(array, low, pi - 1)
#   [Previous line repeated 990 more times]
#   File "/home/myuser/RayMasteryCheckpoint/qs.py", line 32, in quickSort
#     pi = partition(array, low, high)
#   File "/home/myuser/RayMasteryCheckpoint/qs.py", line 13, in partition
#     for j in range(low, high):
# RecursionError: maximum recursion depth exceeded in comparison

# %%
is_sorted(result_ss)
# Out:
# True

# %%
# create an array with 10,000,000 ints from 0 to max size 
arr = np.random.randint(0, sys.maxsize, size=10000000)
available_processors = int(ray.available_resources()['CPU'])

# %%
# %%time
result_qs = qs.quickSort(arr, 0, len(arr)-1)
# Out:
# CPU times: user 54 s, sys: 56.2 ms, total: 54 s
# Wall time: 55.5 s

# %%
is_sorted(result_qs)
# Out:
# True
